# %% [markdown]
# <a href="https://colab.research.google.com/github/Kazureect/ExploratoryDataAnalysis_Project1/blob/main/GREE_1300_Most_commonly_used_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Read Dataset

# %%
# Importing the pandas library to read the dataset
import pandas as pd

# read csv dataset with pd.read_csv() syntax
df = pd.read_csv("GRE-1300 Most commonly used words.csv")

# %%
df
# Out:
#              Word                                            Meaning  \
# 0            note                             a brief written record
# 1           board                      a stout length of sawn timber
# 2           claim                          assert or affirm strongly
# 3       opportune  suitable or advantageous especially for a part...
# 4           weary                   physically and mentally fatigued
# ...           ...                                                ...
# 1300        aerie  the lofty nest of a bird of prey, such as a ha...
# 1301  pulchritude             physical beauty, especially of a woman
# 1302      orotund                 overly formal and pompous in style
# 1303       precis  a sketchy summary of the main points of an arg...
# 1304    analgesia  absence of the sense of pain without loss of c...
#
#       Frequency
# 0         22.96
# 1         37.28
# 2         39.30
# 3         53.22
# 4         84.74
# ...         ...
# ...

# %% [markdown]
# # 2. Data Summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1305 entries, 0 to 1304
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Word       1304 non-null   object
#  1   Meaning    1304 non-null   object
#  2   Frequency  1304 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 30.7+ KB

# %% [markdown]
# # 3. Checking for Missing Data (Missing Value)

# %%
# checking for missing value
df.isna().sum()
# Out:
# Word         1
# Meaning      1
# Frequency    1
# dtype: int64

# %%
# checking for statisticial summary
df.describe()
# Out:
#            Frequency
# count    1304.000000
# mean     5155.365859
# std     10865.247043
# min        22.960000
# 25%      1068.972500
# 50%      2262.440000
# 75%      4890.077500
# max    139051.710000

# %%
# checking for statisticial summary
df['Frequency'].describe()
# Out:
# count      1304.000000
# mean       5155.365859
# std       10865.247043
# min          22.960000
# 25%        1068.972500
# 50%        2262.440000
# 75%        4890.077500
# max      139051.710000
# Name: Frequency, dtype: float64

# %%
# Resolve missing values
for column in df.columns:
    if df[column].dtype == 'object':
        # If the column is object type, fill it with mode
        df[column].fillna(df[column].mode()[0], inplace=True)
    else:
        # If the column is numeric type and the distribution is Skewness, fill it with the mode
        df[column].fillna(df[column].median(), inplace=True)
# Out:
# /tmp/ipython-input-36-4061131914.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mode()[0], inplace=True)
# /tmp/ipython-input-36-4061131914.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Recheck missing values
df.isna().sum()
# Out:
# Word         0
# Meaning      0
# Frequency    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1305 entries, 0 to 1304
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Word       1305 non-null   object
#  1   Meaning    1305 non-null   object
#  2   Frequency  1305 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 30.7+ KB

# %% [markdown]
# # 4. Resolve Duplicate Data

# %%
check_duplicate = df.duplicated().sum()

print(f"Number of duplicates data = {check_duplicate}")
# Out:
# Number of duplicates data = 138

# %%
# Handling duplicates
df = df.drop_duplicates()

# %%
# Check duplicates after handling
handle_duplicate = df.duplicated().sum()

print(f"Number of duplicates data = {handle_duplicate}")
# Out:
# Number of duplicates data = 0
